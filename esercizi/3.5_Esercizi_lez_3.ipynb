# %% [markdown]
# ### **1.Consumo di alcol per paese**
# Esegui un’**analisi esplorativa** focalizzata sul **consumo di alcol**.
# Analizza i seguenti aspetti:
# * Visualizza i primi 10 paesi ordinati per total_litres_of_pure_alcohol (dal più alto)
#
# * Calcola la media del consumo di birra, vino, e distillati
#
# * Crea una nuova colonna alcohol_index che sia: `(beer_servings + wine_servings + spirit_servings) / 3`
#
# * Trova il paese con il valore massimo di alcohol_index
#
# * Filtra solo i paesi che consumano più di 100 birre all’anno
#
# Crea un bar chart dei 10 paesi con più consumo totale (total_litres_of_pure_alcohol)
#
# Crea un line plot con wine_servings ordinato per paese (usa sort_values)

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/alcohol-consumption/drinks.csv")
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# 4                             5.9
# ..                            ...
# 188                           7.7
# 189                           2.0
# 190                           0.1
# 191                           2.5
# 192                           4.7
#
# [193 rows x 5 columns]

# %%
df.sort_values(by = 'total_litres_of_pure_alcohol', ascending = False).head(10)
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 15              Belarus            142              373             42
# 98            Lithuania            343              244             56
# 3               Andorra            245              138            312
# 68              Grenada            199              438             28
# 61               France            127              151            370
# 45       Czech Republic            361              170            134
# 141  Russian Federation            247              326             73
# 99           Luxembourg            236              133            271
# 155            Slovakia            196              293            116
# 81              Ireland            313              118            165
#
#      total_litres_of_pure_alcohol
# 15                           14.4
# 98                           12.9
# 3                            12.4
# 68                           11.9
# 61                           11.8
# 45                           11.8
# 141                          11.5
# 99                           11.4
# 155                          11.4
# 81                           11.4

# %%
media_birra = df['beer_servings'].mean()
media_vino = df['wine_servings'].mean()
media_distillati = df['spirit_servings'].mean()

# %%
nuovacolonna = (df['beer_servings'] + df['wine_servings'] + df['spirit_servings']) / 3
df['alcohol_index'] = nuovacolonna
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol  alcohol_index
# 0                             0.0       0.000000
# 1                             4.9      91.666667
# 2                             0.7      13.000000
# 3                            12.4     231.666667
# 4                             5.9     106.333333
# ..                            ...            ...
# 188                           7.7     145.333333
# 189                           2.0      38.000000
# 190                           0.1       2.000000
# 191                           2.5      18.333333
# 192                           4.7      28.666667
#
# [193 rows x 6 columns]

# %%
df.sort_values('alcohol_index', ascending = False).head(1)['country']
# Out:
# 3    Andorra
# Name: country, dtype: str

# %%
df['beer_servings'] > 100
df[df['beer_servings'] > 100]
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 3              Andorra            245              138            312
# 4               Angola            217               57             45
# 5    Antigua & Barbuda            102              128             45
# 6            Argentina            193               25            221
# 8            Australia            261               72            212
# ..                 ...            ...              ...            ...
# 182     United Kingdom            219              126            195
# 184                USA            249              158             84
# 185            Uruguay            115               35            220
# 188          Venezuela            333              100              3
# 189            Vietnam            111                2              1
#
#      total_litres_of_pure_alcohol  alcohol_index
# 3                            12.4     231.666667
# 4                             5.9     106.333333
# 5                             4.9      91.666667
# 6                             8.3     146.333333
# 8                            10.4     181.666667
# ..                            ...            ...
# 182                          10.4     180.000000
# 184                           8.7     163.666667
# 185                           6.6     123.333333
# 188                           7.7     145.333333
# 189                           2.0      38.000000
#
# [79 rows x 6 columns]

# %%
import pandas as pd
# %pip install matplotlib
import matplotlib.pyplot as plt

top_10_consumers = df.nlargest(10, 'total_litres_of_pure_alcohol')


plt.bar(top_10_consumers['country'], top_10_consumers['total_litres_of_pure_alcohol'], color='skyblue')
plt.xlabel('Paese')
plt.ylabel('Litri totali di alcol puro')
plt.title('Top 10 Paesi per Consumo di Alcol')
plt.show()
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.11.1-cp313-cp313-win_amd64.whl.metadata (80 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.28.2 (from matplotlib)
#   Downloading fonttools-4.64.0-cp313-cp313-win_amd64.whl.metadata (126 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.1-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.25 in c:\labprogrammazione_ii_2026\.venv\lib\site-packages (from matplotlib) (2.5.2)
# Requirement already satisfied: packaging>=20.0 in c:\labprogrammazione_ii_2026\.venv\lib\site-packages (from matplotlib) (26.3)
# Collecting pillow>=9 (from matplotlib)
#   Using cached pillow-12.3.0-cp313-cp313-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\labprogrammazione_ii_2026\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\labprogrammazione_ii_2026\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached matplotlib-3.11.1-cp313-cp313-win_amd64.whl (9.3 MB)
# Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.64.0-cp313-cp313-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    --------------------- ------------------ 1.3/2.5 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 7.7 MB/s  0:00:00
# Downloading kiwisolver-1.5.1-cp313-cp313-win_amd64.whl (70 kB)
# Using cached pillow-12.3.0-cp313-cp313-win_amd64.whl (7.2 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------- ---------------------------- 2/7 [kiwisolver]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------------- 7/7 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.64.0 kiwisolver-1.5.1 matplotlib-3.11.1 pillow-12.3.0 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
df_sorted = df.sort_values(by='country')

plt.plot(df_sorted['country'], df_sorted['wine_servings'], marker='o', linestyle='-', color='darkred', markersize=1)
plt.xlabel('Paese')
plt.ylabel('Wine Servings')
plt.title('Consumo di Vino per Paese (Ordine Alfabetico)')

plt.show()

# %% [markdown]
# ### **2.Analisi offerte di lavoro**
#
# Esegui un’**analisi esplorativa** focalizzata sui **lavori nel campo dei dati in ciascun paese**.
# Analizza i seguenti aspetti per ogni paese:
#
# * Lo **stipendio medio annuale** (`salary_year_avg`)
# * Il **numero totale di offerte di lavoro** (job count)
# * L’intervallo degli stipendi: **valore minimo e massimo** (`min` / `max`)
#
# Rappresenta graficamente lo stipendio medio (`salary_year_avg`) per `job_title_short` usando un grafico a barre orizzontali. Ordina i dati dallo stipendio più alto al più basso. Includi un titolo e le etichette per gli assi x e y.

# %%
import pandas as pd
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 2
#       1 import pandas as pd
# ----> 2 from datasets import load_dataset
#       3
#       4 dataset = load_dataset('lukebarousse/data_jobs')
#       5 df = dataset['train'].to_pandas()
#
# ModuleNotFoundError: No module named 'datasets'

# %%
import matplotlib.pyplot as plt

df
df_salary = df.dropna(subset=['salary_year_avg'])
df_salary

country_analysis = df_salary.groupby('job_country')['salary_year_avg'].agg(
    salary_mean='mean',
    job_count='count',
    salary_min='min',
    salary_max='max'
).sort_values(by='job_count', ascending=False)

print("Analisi esplorativa per Paese (primi 10):")
print(country_analysis.head(10))

# Calcolo stipendio medio per titolo di lavoro
job_title_salary = df_salary.groupby('job_title_short')['salary_year_avg'].mean().sort_values(ascending=True)

plt.figure(figsize=(10, 6))
job_title_salary.plot(kind='barh', color='skyblue', edgecolor='black')

plt.title('Stipendio Medio Annuale per Titolo di Lavoro')
plt.xlabel('Stipendio Medio ($)')
plt.ylabel('Titolo di Lavoro')
plt.grid(axis='x', linestyle='--', alpha=0.7)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 4
#       1 import matplotlib.pyplot as plt
#       2
#       3 df
# ----> 4 df_salary = df.dropna(subset=['salary_year_avg'])
#       5 df_salary
#       6
#       7 country_analysis = df_salary.groupby('job_country')['salary_year_avg'].agg(
#
# File c:\LabProgrammazione_II_2026\.venv\Lib\site-packages\pandas\core\frame.py:7803, in DataFrame.dropna(self, axis, how, thresh, subset, inplace, ignore_index)
#    7799             ax = self._get_axis(agg_axis)
#    7800             indices = ax.get_indexer_for(subset)
#    7801             check = indices == -1
#    7802             if check.any():
# -> 7803                 raise KeyError(np.array(subset)[check].tolist())
#    7804             agg_obj = self.take(indices, axis=agg_axis)
#    7805
#    7806         if thresh is not lib.no_default:
#
# KeyError: ['salary_year_avg']

# %% [markdown]
# ### **3. Analisi vendite (dataset tips)**
#
# Esegui un’**analisi esplorativa** focalizzata sulle **vendite giornaliere**.
# Analizza i seguenti aspetti per ogni giorno (`day`):
#
# * Il **conto medio** (`total_bill`)
# * Il **numero totale di osservazioni** (conteggio delle righe)
# * Il **valore minimo e massimo** del conto (`total_bill` → `min` / `max`)
#
# * Crea una nuova colonna `conto_per_persona` che sia:
#   `total_bill / size`
#
# * Trova il giorno con il **conto medio più alto**
#
# Rappresenta graficamente il **conto medio (`total_bill`) per giorno** usando un **grafico a barre**.
# Ordina i dati dal valore più alto al più basso.
# Aggiungi titolo ed etichette agli assi.

# %%
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
df = pd.read_csv(url)

df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df['conto_per_persona'] = df['total_bill'] / df['size']

analisi = df.groupby('day')['total_bill'].agg(
    mean='mean',
    row_count='count',
    min='min',
    max='max'
).sort_values(by='mean', ascending=False) 

print("Analisi esplorativa per Giorno (ordinata per media):")
print(analisi)


giorno_top = analisi.index[0]
print(f"\nIl giorno con il conto medio più alto è: {giorno_top}")

analisi['mean'].plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Conto Medio per Giorno')
plt.xlabel('Giorno')
plt.ylabel('Media Total Bill ($)')
plt.show()
# Out:
# Analisi esplorativa per Giorno (ordinata per media):
#            mean  row_count   min    max
# day
# Sun   21.410000         76  7.25  48.17
# Sat   20.441379         87  3.07  50.81
# Thur  17.682742         62  7.51  43.11
# Fri   17.151579         19  5.75  40.17
#
# Il giorno con il conto medio più alto è: Sun
